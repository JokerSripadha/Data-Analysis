# %%
import requests

# %%
page = requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/82.jpg","link":"https:\/\/randomfox.ca\/?i=82"}

# %%
print(page.json())
# Out:
# {'image': 'https://randomfox.ca/images/7.jpg', 'link': 'https://randomfox.ca/?i=7'}

# %% [markdown]
# my api = 9c9e2eb5-ffab-4aed-81bd-3130cb966689

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '9c9e2eb5-ffab-4aed-81bd-3130cb966689',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
import requests

def get_weather(city, api_key):
    url = f"https://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
    response = requests.get(url)
    data = response.json()
    return data

def main():
    city = input("Enter city name: ")
    api_key = "YOUR_API_KEY"  # Replace "YOUR_API_KEY" with your actual API key
    weather_data = get_weather(city, api_key)

    if 'error' in weather_data:
        print("Error:", weather_data['error']['message'])
    else:
        print(f"Weather in {city}:")
        print("Condition:", weather_data['current']['condition']['text'])
        print("Temperature (C):", weather_data['current']['temp_c'])
        print("Feels like (C):", weather_data['current']['feelslike_c'])
        print("Humidity:", weather_data['current']['humidity'])
        print("Wind (km/h):", weather_data['current']['wind_kph'])

if __name__ == "__main__":
    main()
# Out:
# {'status': {'timestamp': '2024-02-20T16:32:51.925Z', 'error_code': 0, 'error_message': None, 'elapsed': 0, 'credit_count': 1, 'notice': None}, 'data': [{'id': 5469, 'name': '8112iza22k6', 'symbol': '2nar0xk1ifj', 'slug': '3pcqrksdz4h', 'cmc_rank': 8589, 'num_market_pairs': 3644, 'circulating_supply': 3354, 'total_supply': 9929, 'max_supply': 3272, 'infinite_supply': None, 'last_updated': '2024-02-20T16:32:51.925Z', 'date_added': '2024-02-20T16:32:51.925Z', 'tags': ['goxkg9e91rf', 'e3z1yxtnbsa', 'u0fgg7fo42', 'v7mhx3ngf1l', 'a4e5pf130dl', 'ovsquil1nx', '3y8kp3mw53r', 'b8ptrilzot6', 'cte6n0x10qp', 'imlvrccdul'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.9444437243873756, 'volume_24h': 5357, 'volume_change_24h': 0.1880772452635524, 'percent_change_1h': 0.35094402768966493, 'percent_change_24h': 0.5329524137142021, 'percent_change_7d': 0.025195103043424982, 'market_cap': 0.23188611364476253, 'market_cap_dominance': 545, 'fully_diluted_market_cap': 0.7823097700805421, 'last_updated': '2024-02-20T16:32:51.925Z'}}}, {'id': 8225, 'name': 'b4lkapkz7g', 'symbol': '9lvfqqws1cp', 'slug': 'vkre0ptcwke', 'cmc_rank': 580, 'num_market_pairs': 9927, 'circulating_supply': 6950, 'total_supply': 3574, 'max_supply': 7336, 'infinite_supply': None, 'last_updated': '2024-02-20T16:32:51.925Z', 'date_added': '2024-02-20T16:32:51.925Z', 'tags': ['ov6hkmt2bc', 'g1lqlegzsm', 'rs7w1ynihwi', 'uowa57i664c', 'bf8p6o371ke', 'oaorzk2rt2i', 'hpgeoqpn0a', 'f7m77q0skai', 'k45c8cyzwu', 'kg88nm5oyp'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.22451497945981558, 'volume_24h': 9221, 'volume_change_24h': 0.17627989889061046, 'percent_change_1h': 0.6600853697531419, 'percent_change_24h': 0.023558081994131008, 'percent_change_7d': 0.1160143256710724, 'market_cap': 0.011205565844033538, 'market_cap_dominance': 9054, 'fully_diluted_market_cap': 0.22326479674743482, 'last_updated': '2024-02-20T16:32:51.925Z'}}}, {'id': 2871, 'name': 'uxdlf0nnrzn', 'symbol': 'ovy8nwoaf7n', 'slug': 'izvm88c2haa', 'cmc_rank': 1965, 'num_market_pairs': 5025, 'circulating_supply': 9831, 'total_supply': 3015, 'max_supply': 2099, 'infinite_supply': None, 'last_updated': '2024-02-20T16:32:51.925Z', 'date_added': '2024-02-20T16:32:51.925Z', 'tags': ['nqdru640f5q', '4gyqzmju7s4', 'musy4sbhja', 'r22aiiis17c', 'yia8ef58cup', 'mc4oycz5kc', 'plb2h3itjrq', 'nqfvgowd8w', '6qhrp6kh7go', 'iyqv6vs4v8r'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.002418477854487344, 'volume_24h': 8270, 'volume_change_24h': 0.42459890228035935, 'percent_change_1h': 0.9820971807637786, 'percent_change_24h': 0.36577412974145096, 'percent_change_7d': 0.12930375702076002, 'market_cap': 0.3409772123907586, 'market_cap_dominance': 5326, 'fully_diluted_market_cap': 0.5682508118410865, 'last_updated': '2024-02-20T16:32:51.925Z'}}}, {'id': 8293, 'name': 'j8vgp5ypben', 'symbol': '2a9zxeaheme', 'slug': 'zndxfwyksps', 'cmc_rank': 508, 'num_market_pairs': 6524, 'circulating_supply': 6581, 'total_supply': 5729, 'max_supply': 5324, 'infinite_supply': None, 'last_updated': '2024-02-20T16:32:51.925Z', 'date_added': '2024-02-20T16:32:51.925Z', 'tags': ['7fybplplhka', '3el7py6sid6', 'p6gipz5sd', '1ir7yqs4jnn', 'xklw4i3k9vj', '70b8z965b3a', 'qn97g4kyop', '0531xyjswsxx', '6hpo50l1d6j', 'p6iy7tspxwh'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.39517438042305275, 'volume_24h': 947, 'volume_change_24h': 0.715822671686023, 'percent_change_1h': 0.5006716471806651, 'percent_change_24h': 0.5304894077746611, 'percent_change_7d': 0.6046478288045862, 'market_cap': 0.8126821280747363, 'market_cap_dominance': 5292, 'fully_diluted_market_cap': 0.1282532772314613, 'last_updated': '2024-02-20T16:32:51.925Z'}}}, {'id': 3806, 'name': 'z3lnhy76el', ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm =pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  5469  8112iza22k6  2nar0xk1ifj  3pcqrksdz4h      8589              3644
# 1  8225   b4lkapkz7g  9lvfqqws1cp  vkre0ptcwke       580              9927
# 2  2871  uxdlf0nnrzn  ovy8nwoaf7n  izvm88c2haa      1965              5025
# 3  8293  j8vgp5ypben  2a9zxeaheme  zndxfwyksps       508              6524
# 4  3806   z3lnhy76el  u1oadi1aetl  ej4nxk7o1kp      6635              2946
# 5  9363  6t576k022dy  j58bxriofob  zzm5akd3tq8      1255              2409
# 6  6765  prp9ry9s22q   us6cxddbdj  ydj2gzyzclt      4654              8009
# 7  8924  8ax528imyjn  d3mxb1k30l5  j6h49uuy85f      4490              2368
# 8  7357  5ha46qd2hsu  d2zotfer0ub  ekl1tm46c4l      3081              3471
# 9  4379  qbb5iagyerc   9eviuo4x1a   n26iki2vfv      3287              4238
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                3354          9929        3272            None  ...
# 1                6950          3574        7336            None  ...
# 2                9831          3015        2099            None  ...
# 3                6581          5729        5324            None  ...
# 4                1333          7157         298            None  ...
# 5                3946          3684        2919            None  ...
# 6                5523          4826         985            None  ...
# 7                2659          1177        9073            None  ...
# 8                3196          3956        4058            None  ...
# 9                3173          2523        9584            None  ...
#
#   quote.USD.price quote.USD.volume_24h quote.USD.volume_change_24h  \
# 0        0.944444                 5357                    0.188077
# 1        0.224515                 9221                    0.176280
# 2        0.002418                 8270                    0.424599
# 3        0.395174                  947                    0.715823
# 4        0.824355                 7228                    0.213661
# 5        0.848907                 3955                    0.480911
# 6        0.019889                  213                    0.674183
# 7        0.093064                 8173                    0.399025
# 8        0.544428                  344                    0.071635
# 9        0.456357                 1650                    0.375020
#
#   quote.USD.percent_change_1h quote.USD.percent_change_24h  \
# 0                    0.350944                     0.532952
# 1                    0.660085                     0.023558
# 2                    0.982097                     0.365774
# 3                    0.500672                     0.530489
# 4                    0.440577                     0.947176
# 5                    0.932461                     0.278615
# 6                    0.076371                     0.901759
# 7                    0.733118                     0.957821
# 8                    0.868085                     0.409953
# 9                    0.969427                     0.255228
#
#   quote.USD.percent_change_7d  quote.USD.market_cap  \
# 0                    0.025195              0.231886
# 1                    0.116014              0.011206
# 2                    0.129304              0.340977
# 3                    0.604648              0.812682
# 4                    0.065806              0.387124
# 5                    0.760477              0.374654
# 6                    0.894857              0.312526
# 7                    0.362322              0.793817
# 8                    0.037711              0.398793
# 9                    0.889199              0.241772
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                             545                            0.782310
# 1                            9054                            0.223265
# 2                            5326                            0.568251
# 3                            5292                            0.128253
# 4                            2744                            0.308904
# 5                             108                            0.772588
# 6                             822                            0.531133
# 7                            2486                            0.804990
# 8                            3936                            0.610824
# 9                            1049                            0.888867
#
#      quote.USD.last_updated
# 0  2024-02-20T16:32:51.925Z
# 1  2024-02-20T16:32:51.925Z
# 2  2024-02-20T16:32:51.925Z
# 3  2024-02-20T16:32:51.925Z
# 4  2024-02-20T16:32:51.925Z
# 5  2024-02-20T16:32:51.925Z
# 6  2024-02-20T16:32:51.925Z
# 7  2024-02-20T16:32:51.925Z
# 8  2024-02-20T16:32:51.925Z
# 9  2024-02-20T16:32:51.925Z
#
# [10 rows x 26 columns]

# %%
import requests

api_key = 'a6397a3666834e188b7162940242002'

def get_weather(city, api_key):
    url = f"https://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
    response = requests.get(url)
    data = response.json()
    return data

def main():
    city = input("Enter city name: ")
    weather_data = get_weather(city, api_key)

    if 'error' in weather_data:
        print("Error:", weather_data['error']['message'])
    else:
        print(f"Weather in {city}:")
        print("Condition:", weather_data['current']['condition']['text'])
        print("Temperature (C):", weather_data['current']['temp_c'])
        print("Feels like (C):", weather_data['current']['feelslike_c'])
        print("Humidity:", weather_data['current']['humidity'])
        print("Wind (km/h):", weather_data['current']['wind_kph'])

if __name__ == "__main__":
    main()
# Out:
# Enter city name: Tanuku
# Weather in Tanuku:
# Condition: Clear
# Temperature (C): 21.9
# Feels like (C): 21.9
# Humidity: 5.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-0888e4fd3d4c> in <cell line: 25>()
#      24
#      25 if __name__ == "__main__":
# ---> 26     main()
#
# <ipython-input-21-0888e4fd3d4c> in main()
#      21         print("Feels like (C):", weather_data['current']['feelslike_c'])
#      22         print("Humidity:", weather_data['current']['wind_kph'])
# ---> 23         print("Wind (km/h):", weather_data['current']['co'])
#      24
#      25 if __name__ == "__main__":
#
# KeyError: 'co'
